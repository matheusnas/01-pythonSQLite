# %%
import duckdb as db

# %%
con = db.connect(database='dados_duckdb.db', read_only=False)

# %%
df = con.execute("""
                show tables;
                """).fetchdf()
df
# Out:
# Empty DataFrame
# Columns: [name]
# Index: []
